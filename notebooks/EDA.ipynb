# %% [markdown]
# ## 0. Imports

# %%
import pandas as pd
import seaborn as sns
import opendatasets as od

# %% [markdown]
# ## 1. Download data

# %%
# !pip install opendatasets
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %% [markdown]
# You must enter your Kaggle username and API key in order to download the dataset below:

# %%
od.download(
	"https://www.kaggle.com/datasets/cherngs/heart-disease-cleveland-uci"
  )
# Out:
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username: levbara
# Your Kaggle Key: ··········
# ...
# 100%|██████████| 3.33k/3.33k [00:00<00:00, 1.12MB/s]

# %% [markdown]
# **Hint**: You can create your API key here: https://www.kaggle.com/ *your_username*/account

# %% [markdown]
# ## 2. Import data

# %%
df = pd.read_csv("/content/heart-disease-cleveland-uci/heart_cleveland_upload.csv")

# %% [markdown]
# ## 3. Analyze features

# %%
df.head(5)
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   69    1   0       160   234    1        2      131      0      0.1      1
# 1   69    0   0       140   239    0        0      151      0      1.8      0
# 2   66    0   0       150   226    0        0      114      0      2.6      2
# 3   65    1   0       138   282    1        2      174      0      1.4      1
# 4   64    1   0       110   211    0        2      144      1      1.8      1
#
#    ca  thal  condition
# 0   1     0          0
# 1   2     0          0
# 2   0     0          0
# 3   1     0          1
# 4   0     0          0

# %%
print("Dataset's shape:", df.shape)
# Out:
# Dataset's shape: (297, 14)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 297 entries, 0 to 296
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        297 non-null    int64
#  1   sex        297 non-null    int64
#  2   cp         297 non-null    int64
#  3   trestbps   297 non-null    int64
#  4   chol       297 non-null    int64
#  5   fbs        297 non-null    int64
#  6   restecg    297 non-null    int64
#  7   thalach    297 non-null    int64
#  8   exang      297 non-null    int64
#  9   oldpeak    297 non-null    float64
#  10  slope      297 non-null    int64
#  11  ca         297 non-null    int64
#  12  thal       297 non-null    int64
#  13  condition  297 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 32.6 KB

# %%
print("Duplicates in dataset:", df.duplicated().sum(), '\n')
print("NA values:", df.isna().sum(), sep='\n')
# Out:
# Duplicates in dataset: 0
#
# NA values:
# age          0
# sex          0
# cp           0
# trestbps     0
# chol         0
# fbs          0
# restecg      0
# thalach      0
# exang        0
# oldpeak      0
# slope        0
# ca           0
# thal         0
# condition    0
# dtype: int64

# %%
print(df.condition.value_counts())
# Out:
# 0    160
# 1    137
# Name: condition, dtype: int64

# %%
print(df.nunique())
# Out:
# age           41
# sex            2
# cp             4
# trestbps      50
# chol         152
# fbs            2
# restecg        3
# thalach       91
# exang          2
# oldpeak       40
# slope          3
# ca             4
# thal           3
# condition      2
# dtype: int64

# %% [markdown]
# **Summary:**
#
# *   No duplicates
# *   No NA values
# *   Balanced target
# *   Features:
#   *   Numeric: age,trestbps, chol, thalach, oldpeak
#   *   Categorical: sex, cp, fbs, restecg, exang, slope, ca, thal
# *   Target: condition

# %% [markdown]
# ## 4. Visualization

# %% [markdown]
# Visualize correlation heatmap:

# %%
sns.set(rc={"figure.figsize": (16, 9)})
sns.heatmap(df.corr(), annot=True)

# %% [markdown]
# Show histograms of features distibution:

# %%
df.hist(figsize=(20, 15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f2ec5489690>,
# ...
#       dtype=object)

# %%
sns.pairplot(df, hue="condition")
